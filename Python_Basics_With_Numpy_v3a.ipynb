# %% [markdown]
# 带有Numpy的Python基础知识（可选分配）
# 欢迎来到您的第一份作业。本练习为您简要介绍了Python。即使您以前使用过Python，也可以帮助您熟悉我们需要的功能。
#
# 指示：
#
# 您将使用Python 3。
# 避免使用for循环和while循环，除非明确要求您这样做。
# 在某些单元格中请勿修改（＃GRADED FUNCTION [功能名称]）注释。如果您对此进行更改，则不会对您的作品评分。每个包含该注释的单元格应只包含一个函数。
# 对函数进行编码后，运行它下面的单元格以检查结果是否正确。
# 完成此任务后，您将：
#
# 能够使用iPython笔记本
# 能够使用numpy函数和numpy矩阵/向量运算
# 了解“广播”的概念
# 能够向量化代码
# 让我们开始吧

# %% [markdown]
# 作业更新
# 这是笔记本的3a版本。
#
# 如果您使用的是以前的版本
# 如果您已经在使用版本“ 3”，则将在文件目录中找到您的原始作品。
# 要访问文件目录，请单击此笔记本左上方的“ Coursera”图标。
# 请仍然使用最新的笔记本来提交作业。
# 更新清单
# softmax部分有评论以澄清本课程后面的“ m”的使用
# softmax函数指定（m，n）矩阵尺寸以匹配上图中的符号（而不是n，m）
# 关于iPython笔记本
# iPython Notebook是嵌入在网页中的交互式编码环境。您将在此类中使用iPython笔记本。您只需要在### START CODE HERE ###和### END CODE HERE ###注释之间编写代码。编写代码后，您可以通过按“ SHIFT” +“ ENTER”或单击笔记本上部栏中的“运行单元”（由播放符号表示）来运行该单元。
#
# 我们通常会在注释中指定“（≈X行代码）”，以告诉您需要编写多少代码。这只是一个粗略的估计，因此，如果您的代码更长或更短，也不要感到难过。
#
# 练习：在下面的单元格中将测试设置为“ Hello World”，以打印“ Hello World”并运行下面的两个单元格。

# %%
### START CODE HERE ### (≈ 1 line of code)
test = "Hello World"
### END CODE HERE ###

# %%
print ("test: " + test)
# Out:
# test: Hello World

# %% [markdown]
# 您需要记住的是：
#
# 使用SHIFT + ENTER（或“运行单元格”）运行单元格
# 仅使用Python 3在指定区域内编写代码
# 请勿在指定区域以外修改代码
# 1-使用numpy构建基本功能
# Numpy是Python中用于科学计算的主要软件包。它由一个大型社区（www.numpy.org）维护。在本练习中，您将学习一些关键的numpy函数，例如np.exp，np.log和np.reshape。您将需要知道如何在以后的分配中使用这些功能。
#
# 1.1-sigmoid函数，np.exp（）¶
# 在使用np.exp（）之前，您将使用math.exp（）来实现Sigmoid函数。然后，您将了解为什么np.exp（）比math.exp（）更可取。
#
# 练习：构建一个返回实数x的S形的函数。将math.exp（x）用于指数函数。
# Reminder:有时也称为逻辑函数。它是一种非线性函数，不仅用于机器学习（逻辑回归），而且还用于深度学习。sigmoid(x)=11+e−x     ![image.png](attachment:image.png)要引用属于特定程序包的函数，可以使用package_name.function（）对其进行调用。运行下面的代码以查看带有math.exp（）的示例。

# %%
# GRADED FUNCTION: basic_sigmoid

import math

def basic_sigmoid(x):
    """
    Compute sigmoid of x.

    Arguments:
    x -- A scalar

    Return:
    s -- sigmoid(x)
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    s = 1/(1+math.exp(-x))
    ### END CODE HERE ###
    
    return s

# %%
basic_sigmoid(3)
print(basic_sigmoid(3))
# Out:
# 0.9525741268224334

# %% [markdown]
# Expected Output:
#
# basic_sigmoid(3)	0.9525741268224334

# %% [markdown]
# 实际上，我们很少在深度学习中使用“数学”库，因为函数的输入是实数。在深度学习中，我们主要使用矩阵和向量。这就是为什么numpy更有用的原因。

# %%
### One reason why we use "numpy" instead of "math" in Deep Learning ###
x = [1, 2, 3]
basic_sigmoid(x) # you will see this give an error when you run it, because x is a vector.

# %% [markdown]
# In fact, if  x=(x1,x2,...,xn)x=(x1,x2,...,xn)  is a row vector then  np.exp(x)np.exp(x)  will apply the exponential function to every element of x. The output will thus be:  np.exp(x)=(ex1,ex2,...,exn)np.exp(x)=(ex1,ex2,...,exn)

# %%
import numpy as np

# example of np.exp
x = np.array([1, 2, 3])
print(np.exp(x)) # result is (exp(1), exp(2), exp(3))
# Out:
# [ 2.71828183  7.3890561  20.08553692]

# %% [markdown]
# Furthermore, if x is a vector, then a Python operation such as  s=x+3s=x+3  or  s=1xs=1x  will output s as a vector of the same size as x.

# %%
# example of vector operation
x = np.array([1, 2, 3])
print (x + 3)
# Out:
# [4 5 6]

# %% [markdown]
# 每当您需要有关numpy函数的更多信息时，我们建议您查看官方文档。
#
# 您还可以在笔记本中创建一个新单元格并编写np.exp？ （例如）以快速访问文档。
#
# 练习：使用numpy实现S形函数。
#
# 说明：x现在可以是实数，向量或矩阵。我们在numpy中使用的表示这些形状（矢量，矩阵等）的数据结构称为numpy数组。您现在不需要了解更多。
# **Instructions**: x could now be either a real number, a vector, or a matrix. The data structures we use in numpy to represent these shapes (vectors, matrices...) are called numpy arrays. You don't need to know more for now.
# $$ \text{For } x \in \mathbb{R}^n \text{,     } sigmoid(x) = sigmoid\begin{pmatrix}
#     x_1  \\
#     x_2  \\
#     ...  \\
#     x_n  \\
# \end{pmatrix} = \begin{pmatrix}
#     \frac{1}{1+e^{-x_1}}  \\
#     \frac{1}{1+e^{-x_2}}  \\
#     ...  \\
#     \frac{1}{1+e^{-x_n}}  \\
# \end{pmatrix}\tag{1} $$

# %%
import numpy as np # this means you can access numpy functions by writing np.function() instead of numpy.function()

def sigmoid(x):
    """
    Compute the sigmoid of x

    Arguments:
    x -- A scalar or numpy array of any size

    Return:
    s -- sigmoid(x)
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    s = 1/(1+np.exp(-x))
    ### END CODE HERE ###
    
    return s

# %%
x = np.array([1, 2, 3])
print(sigmoid(x))
# Out:
# [0.73105858 0.88079708 0.95257413]

# %% [markdown]
# ### 1.2 - Sigmoid gradient
#
# As you've seen in lecture, you will need to compute gradients to optimize loss functions using backpropagation. Let's code your first gradient function.
#
# **Exercise**: Implement the function sigmoid_grad() to compute the gradient of the sigmoid function with respect to its input x. The formula is: $$sigmoid\_derivative(x) = \sigma'(x) = \sigma(x) (1 - \sigma(x))\tag{2}$$
# You often code this function in two steps:
# 1. Set s to be the sigmoid of x. You might find your sigmoid(x) function useful.
# 2. Compute $\sigma'(x) = s(1-s)$

# %%
# GRADED FUNCTION: sigmoid_derivative

def sigmoid_derivative(x):
    """
    Compute the gradient (also called the slope or derivative) of the sigmoid function with respect to its input x.
    You can store the output of the sigmoid function into variables and then use it to calculate the gradient.
    
    Arguments:
    x -- A scalar or numpy array

    Return:
    ds -- Your computed gradient.
    """
    
    ### START CODE HERE ### (≈ 2 lines of code)
    s = 1/(1+np.exp(-x))
    ds = s*(1-s)
    ### END CODE HERE ###
    
    return ds

# %%
x = np.array([1, 2, 3])
print ("sigmoid_derivative(x) = " + str(sigmoid_derivative(x)))
# Out:
# sigmoid_derivative(x) = [0.19661193 0.10499359 0.04517666]

# %% [markdown]
# **Expected Output**:
#
#
# <table>
#     <tr>
#         <td> **sigmoid_derivative([1,2,3])**</td>
#         <td> [ 0.19661193  0.10499359  0.04517666] </td>
#     </tr>
# </table>

# %% [markdown]
# ### 1.3 - Reshaping arrays ###
#
# Two common numpy functions used in deep learning are [np.shape](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.shape.html) and [np.reshape()](https://docs.scipy.org/doc/numpy/reference/generated/numpy.reshape.html).
# - X.shape is used to get the shape (dimension) of a matrix/vector X.
# - X.reshape(...) is used to reshape X into some other dimension.
#
# For example, in computer science, an image is represented by a 3D array of shape $(length, height, depth = 3)$. However, when you read an image as the input of an algorithm you convert it to a vector of shape $(length*height*3, 1)$. In other words, you "unroll", or reshape, the 3D array into a 1D vector.
#
#
#
# **Exercise**: Implement `image2vector()` that takes an input of shape (length, height, 3) and returns a vector of shape (length\*height\*3, 1). For example, if you would like to reshape an array v of shape (a, b, c) into a vector of shape (a*b,c) you would do:
# ``` python
# v = v.reshape((v.shape[0]*v.shape[1], v.shape[2])) # v.shape[0] = a ; v.shape[1] = b ; v.shape[2] = c
# ```
# - Please don't hardcode the dimensions of image as a constant. Instead look up the quantities you need with `image.shape[0]`, etc.
